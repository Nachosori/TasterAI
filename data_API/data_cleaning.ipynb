# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import pandas as pd
from pymongo import MongoClient
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
client = MongoClient(os.getenv("URL"))
db = client.get_database("Project")

# %%
data_nutricional = [
      {
        "name": "carrot_cake",
        "tamaño de la porción": 100,
        "kilocalories": 381,
        "grease": 22.00,
        "saturated fat" : 7.600,
        "carbohydrates": 40.00,
        "sugar": 28.00,
        "fiber": 1.2,
        "protein": 5.20,
        "sal": 0.00
      },
      {
        "name": "cheesecake",
        "tamaño de la porción": 100,
        "kilocalories": 320,
        "grease": 19.2,
        "saturated fat" : 7.68,
        "carbohydrates": 29.12,
        "sugar": 22.03,
        "fiber": 0.3,
        "protein": 8.67,
        "sal": 0.94
      },
      {
        "name": "chocolate_cake",
        "tamaño de la porción": 100,
        "kilocalories": 425,
        "grease": 23.00,
        "saturated fat" : 12.00,
        "carbohydrates": 49.00,
        "sugar": 32.00,
        "fiber": 2.9,
        "protein": 5.30,
        "sal": 0.00
      },
      {
        "name": "cup_cakes",
        "tamaño de la porción": 60,
        "kilocalories": 262,
        "grease": 14.20,
        "saturated fat" : 3.200,
        "carbohydrates": 30.50,
        "sugar": 16.50,
        "fiber": 1.1,
        "protein": 3.00,
        "sal": 1.15
      },
      {
        "name": "donuts",
        "tamaño de la porción": 100,
        "kilocalories": 410,
        "grease": 24.00,
        "saturated fat" : 12.00,
        "carbohydrates": 42.00,
        "sugar": 16.00,
        "fiber": 1.10,
        "protein": 5.40,
        "sal": 0.00
      },
      {
        "name": "guacamole",
        "tamaño de la porción": 100,
        "kilocalories": 157,
        "grease": 14.31,
        "saturated fat" : 2.075,
        "carbohydrates": 8.51,
        "sugar": 0.71,
        "fiber": 6.60,
        "protein": 1.96,
        "sal": 0.37
      },
      {
        "name": "gyoza",
        "tamaño de la porción": 100,
        "kilocalories": 175,
        "grease": 7.07,
        "saturated fat" : 2.518,
        "carbohydrates": 16.45,
        "sugar": 0.57,
        "fiber": 0.80,
        "protein": 10.6,
        "sal": 0.86
      },
      {
        "name": "hamburger",
        "tamaño de la porción": 100,
        "kilocalories": 222,
        "grease": 11.29,
        "saturated fat" : 4.333,
        "carbohydrates": 5.10,
        "sugar": 1.09,
        "fiber": 0.20,
        "protein": 23.74,
        "sal": 0.67
      },
      {
        "name": "hot_dog",
        "tamaño de la porción": 100,
        "kilocalories": 285,
        "grease": 4.50,
        "saturated fat" : 0.900,
        "carbohydrates": 49.00,
        "sugar": 4.80,
        "fiber": 2.60,
        "protein": 11.00,
        "sal": 1.10
      },
      {
        "name": "ice_cream",
        "tamaño de la porción": 100,
        "kilocalories": 201,
        "grease": 10.72,
        "saturated fat" : 6.618,
        "carbohydrates": 24.40,
        "sugar": 22.30,
        "fiber": 0.70,
        "protein": 3.52,
        "sal": 0.18
      },
      {
        "name": "macarons",
        "tamaño de la porción": 100,
        "kilocalories": 436,
        "grease": 16.07,
        "saturated fat" : 3.274,
        "carbohydrates": 69.55,
        "sugar": 51.89,
        "fiber": 3.30,
        "protein": 7.03,
        "sal": 0.11
      },
      {
        "name": "nachos",
        "tamaño de la porción": 100,
        "kilocalories": 525,
        "grease": 18.90,
        "saturated fat" : 11.000,
        "carbohydrates": 75.40,
        "sugar": 1.80,
        "fiber": 4.30,
        "protein": 10.40,
        "sal": 0.70
      },
      {
        "name": "paella",
        "tamaño de la porción": 100,
        "kilocalories": 158,
        "grease": 5.44,
        "saturated fat" : 1.193,
        "carbohydrates": 16.68,
        "sugar": 0.62,
        "fiber": 0.60,
        "protein": 9.52,
        "sal": 1.51
      },
      {
        "name": "pizza",
        "tamaño de la porción": 100,
        "kilocalories": 258,
        "grease": 11.37,
        "saturated fat" : 4.178,
        "carbohydrates": 28.87,
        "sugar": 1.52,
        "fiber": 1.40,
        "protein": 9.53,
        "sal": 1.35
      },
      {
        "name": "sushi",
        "tamaño de la porción": 100,
        "kilocalories": 143,
        "grease": 0.42,
        "saturated fat" : 0.087,
        "carbohydrates": 29.90,
        "sugar": 6.27,
        "fiber": 0.80,
        "protein": 4.30,
        "sal": 1.49
      },
    
    
]

# %%
data_aliments = db.data_aliments
data_aliments.insert_many(data_nutricional)

# %%
data_recipes = [
      {
        "type": "carrot_cake",
        "name": "Easy Carrot Cake Recipe",
        "preparation": 10,
        "cooking": 40,
        "ingredients" : ["4 eggs", "150 g cup cane sugar", "200 ml sunflower oil", 
        "300 g greated carrot", "250 g wheat flour", "16 g baking powder", 
        "1 cdta cinnamon powder", " 1 pinch of salt", "80 g chopped wallnuts", 
        "125 g ricotta cheese", "2-4 tbsp. plain yogurt", "2-4 tbsp. of honey"],
        "elaboration": ["1. You can fill the cake or leave it as a sponge cake, so you can make it in a single mold of about 18-20 cm in diameter or in two molds to have two plates and fill the cake. You can also make it in only one mold and then split it in two as I have done. Line the molds with parchment paper and preheat the oven to 180ºC.",
        "2. In a large bowl, beat the eggs with the sugar with a hand or electric whisk. Add the oil and beat until well blended.",
        "3. Incorporate the flour and the baking powder (royal) little by little sifting with a sieve. Add the cinnamon, salt and beat until the dough is homogeneous.",
        "4. Add the grated carrot and walnuts. Mix with a tongue or spoon to integrate everything.",
        "5. Pour the batter into a mold or divide the batter between two molds. Bake at 170ºC for about 40-55 min. Do not open the oven before 30 min. Afterwards you can check if the cake is done if a toothpick comes out clean",
        "6. Remove from the oven and let it cool for 5 minutes, then take it out of the mold and if possible place it on a wire rack and let it cool completely.",
        "7. Meanwhile we will make the frosting but the cake must be cold before putting it on.",
        "8. Blend the cottage cheese or ricotta cheese with the yogurt and honey in a blender until you obtain a fine cream. Keep the frosting in the refrigerator until the cake is completely cold so this frosting will also thicken.",
        "9. You can fill the carrot cake with a thin layer of frosting and then cover the top with another layer or just put the frosting on top of the cake. Decorate with chopped nuts or other dried fruit. "]

      },
      {
        "type": "cheesecake",
        "name": "Quark Cheesecake with Strawberry Topping",
        "preparation": 20,
        "cooking": 0,
        "ingredients" : ["600 g Quark Cheese", "1/4 cup rice milk", "100 g of sugar", 
        "6 sheets of gelatin", "100 g oat flakes", "5 g shredded coconut", 
        "25 g cocoa powder", " 1/4 tsp. cinnamon", "1/4 tsp. salt", 
        "60 g melted coconut oil", "2 tbsp. warm honey"],
        "elaboration": ["1. For the base, grind everything in the food processor and pour it into a mold of about 18 cm in diameter, if possible removable and lining the base with parchment paper. Press the base and the sides a little to compact. Refrigerate.",
        "2. For the filling, hydrate the gelatin in very cold water for about 5 minutes. Once it is ready, drain the leaves and pour them one by one into the milk previously heated in the microwave to dilute them.",
        "3. Heat just a little of the beaten cheese in a saucepan and add the sugar or sweetener of your choice. Remove from the heat and add the milk little by little, stirring constantly.",
        "4. Now pour this mixture over the cooled base carefully. And leave it in the refrigerator for a minimum of 6 hours.",
        "5. Before serving, cover the cake with the strawberry jam and decorate with more strawberries and mint leaves or mint to taste."]
      },
      {
        "type": "chocolate_cake",
        "name": "Chocolate and Mango Cake",
        "preparation": 15,
        "cooking": 30,
        "ingredients" : ["3 eggs", "4 tbsp. water", "40 ml sunflower oil", 
        "100 g brown sugar", "90 g plain flour", "3 tbsp corn flour", 
        "4 tbsp. cocoa", " 1/2 tsp. salt", "1 ripe crushed mango", 
        "75 g dark chocolate 50% min. cocoa coverage", "25 g butter", "1 tbsp. milk"],
        "elaboration": ["1. Pre-heat the oven to 180°C and prepare a 18-22 cm diameter round baking pan with baking paper.",
        "2. In a bowl add the egg yolks, the sugar, the oil and the water. Whip with a whisk until they whiten and double in volume, set aside in the bowl.",
        "3. On the other hand, whip the egg whites until soft peaks form. Without reaching the texture of meringue.",
        "4. Sift the oat flour, cocoa, cornstarch and salt over the bowl of egg yolks and sugar, mix carefully from bottom to top with a tongue or spoon.",
        "5. Add the whipped egg whites and mix with gentle wrapping motions. Add the impeller.",
        "6. Pour the mixture into the baking pan and bake at 180°C for 22-30' (depending on the oven) or until a toothpick inserted comes out clean and dry.",
        "7. Melt the butter in a bowl in a bain-marie without allowing it to come into contact with water.",
        "8. Add the chopped chocolate and wait for it to melt completely.",
        "9. Remove from the heat and add 1 tablespoon of milk, mix well and you can pour the frosting over your cake. Spread it if necessary with a spatula. Let it cool in the refrigerator for about 30'. "]
      },
      {
        "type": "cup_cakes",
        "name": "Simple vanilla cupcakes",
        "preparation": 15,
        "cooking": 25,
        "ingredients" : ["120 grams of all-purpose flour", "140 grams of sugar", "1-1/2 teaspoon baking powder", 
        "1/8 teaspoon salt", "40 grams of unsalted butter, at room temperature", "120 ml liquid milk", 
        "1 egg", "1/2 teaspoon vanilla extract", "1 cup (198 grams) white sugar", 
        "1/3 cup water", "1/4 teaspoon cream of tartar or white vinegar", "1/8 teaspoon salt",
        "2 egg whites"],
        "elaboration": ["1. Heat oven to 325°F / 160°C.",
        "2. Mix the dry ingredients: in a bowl place the flour, sugar, baking powder, salt and butter. Beat with an electric mixer on low speed until everything is integrated and a sandy consistency is achieved",
        "3. Add half of the milk little by little and continue beating until blended.",
        "4. Mix in the egg, vanilla and remaining milk and add to the mixture while continuing to beat until smooth; do not overbeat.",
        "5. Bake the cupcakes: pour the mixture into the cupcake molds to which you have placed the cupcake liners and bake in the oven for about 20 to 25 minutes until golden brown. Test if they are ready by inserting a toothpick and if it comes out dry, they are ready. Be careful not to over bake them, as they will be dry.",
        "6. Pour the mixture into the baking pan and bake at 180°C for 22-30' (depending on the oven) or until a toothpick inserted comes out clean and dry.",
        "7. Cool the cupcakes: transfer the cupcakes to a wire rack to cool completely before decorating.",
        "8. To prepare the frosting: In a small saucepan place the sugar, water, cream of tartar and salt and bring to a boil over medium heat, stirring until the sugar is completely dissolved.",
        "9. In the mixer bowl place the two egg whites, turn on the mixer and gradually add the prepared syrup, beating until stiff peaks form and the bowl temperature drops, about 7 minutes approximately. "]
      },
      {
        "type": "donuts",
        "name": "Homemade donuts, glazed and fluffy",
        "preparation": 50,
        "cooking": 20,
        "ingredients" : ["145 gr of milk", "15 g fresh baker's yeast", "50 g of sugar", 
        "1 egg", "3 g of salt", "320 g wheat flour", 
        "40 g butter", "sunflower oil for frying", "100 g powdered sugar", 
        "2 tbspn. water", "1/2 tspbn vanilla essence"],
        "elaboration": ["1. Bring the milk to the boil and boil for one minute. Let it cool down to 35º C, weigh 145 grams and add the crumbled yeast and 20 grams of sugar. Stir and let the mixture stand for 15 minutes to activate the yeast.",
        "2. Pour the previous mixture into a large bowl and add the egg, the remaining sugar and stir. Then add the flour, sifted, and the salt. Stir well and let stand for 20 minutes to properly moisten the flour particles.",
        "3. Turn the dough out onto the clean, dry table and knead until it becomes smooth and uniform. Add half of the butter and continue kneading until it is integrated. Add the remaining butter and knead again. The total time of kneading is approximately 12 minutes and will vary depending on the ability of each one .",
        "4. Grease a large bowl with a little sunflower oil. Put the dough in it and let it rise until it triples its size. Knead for one minute to degas and let it rest for five minutes to relax. We stretch on the table sprinkled with flour in a sheet of 1 cm thick.",
        "5. Cut out circles with an 8.5 cm dough cutter and with a smaller dough cutter make the holes inside. Gather the remaining dough, knead and cut more doughnuts. Place them on a baking tray covered with baking paper or a silicone mat. Cover with a kitchen towel and let them rest until they double in height.",
        "6. Heat plenty of sunflower oil in a frying pan over medium-low heat. Fry the donuts turning several times so that they brown equally on both sides. To get a nice golden brown, we move them until they are ready. Drain and remove to a dish with absorbent paper.",
        "7. For the glaze, mix the powdered sugar with the water and vanilla essence. Stir until obtaining a homogeneous mixture in which we dip one side of the donuts. Allow to drain on a baking rack for a few minutes before serving."]
      },
      {
        "type": "guacamole",
        "name": "Guacamole Easy Recipe",
        "preparation": 10,
        "cooking": 0,
        "ingredients" : ["1 large avocado", "Juice of 1 lime", "1/2 tomato seeded and chopped", 
        "1/4 red onion", "finely chopped", "1-2 tbsp. chopped fresh cilantro", 
        "2 wheat or corn tortillas", "1 tsp. olive oil", "1/4 tsp. salt"],
        "elaboration": ["1.  Scoop out the avocado pulp with a spoon and chop with a knife. Then mash it with a fork and put it in a bowl. Add the rest of the ingredients, add the lime juice and mix well. Ready!",
        "2. Cut the pancakes into triangles and place them on a baking sheet. Brush a little with the oil, salt and cumin mixture. Bake for 5 minutes at 190 ºC."]
      },
      {
        "type": "gyoza",
        "name": "Recipe for gyoza or Japanese dumplings",
        "preparation": 30,
        "cooking": 30,
        "ingredients" : ["Vegetable or sunflower oil for frying", "1 tablespoon of sesame oil", "Water", 
        "50 patty or gyoza wafers", " 2 onions", "2 cabbage leaves",
        " 8 shiitake mushrooms", "1 grated garlic clove", "2 cm grated fresh ginger",
        "350 gr Minced meat","1 tablespoon sake","1 tablespoon soy",
        "Salt and pepper","1 tablespoon rice vinegar","2 drops of rayu or Japanese chili oil"],
        "elaboration": ["1. First you have to cook the two cabbage leaves using the microwave (1 minute), avoiding that the texture is too crunchy when eating.",
        "2. Continue by cutting the cabbage, onions and mushrooms into several pieces that are very small.",
        "3. In a bowl, add the chopped vegetables, the garlic and ginger (grated) and the minced meat. Mix all the ingredients very well using your hands.",
        "4. Add a tablespoon of sake and one or two tablespoons of soy sauce to the mixture. Also add salt, pepper and mix very well",
        "5. Place one of the gyoza dough wafers on one of your hands and with a wet finger of water from the other hand wet all around the wafer to make it easier to close well.",
        "6. Place a spoonful of the mixture in the center of the wafer. Try not to use too much filling, because if you use too much you will not be able to close it well.",
        "7. Fold the wafer in half.",
        "8. Close the ends little by little and gently.",
        "9. When you have all the Japanese empanadas done, put a tablespoon of vegetable oil in a frying pan over high heat. When the oil is very hot, place the gyozas so that they start frying on the flat side. You can place them in a circle so that they fit more in the pan.",
        "10. Let them fry for 3 - 4 minutes until the underside is golden brown. Now add ¼ (60 ml) of water to the pan and cover immediately.",
        "11. Let the gyozas steam for about 8 minutes (until almost no water is left ",
        "12. To finish, uncover and add a tablespoon of sesame oil to give them a delicious golden brown appearance and shine. Leave them for another minute to finish browning.",
        "13. Now you can transfer them to a serving dish. In a small bowl mix a few tablespoons of soy sauce, rice vinegar and a few drops of rayu and mix. This is the sauce that can be used to intensify their flavor."]
      },
      {
        "type": "hamburger",
        "name": "Homemade hamburger",
        "preparation": 10,
        "cooking": 10,
        "ingredients" : ["1 Sliced bread", "30 ml of Milk", "1 egg", 
        "1 kg Minced beef", "5 g Garlic salt", "5 g Provencal herbs", 
        "30 g of Ketchup", "15 g Dijon mustard"],
        "elaboration": ["1.  In a deep bowl, mix the milk with the egg, ketchup, mustard, garlic salt, Provencal herbs and salt and pepper to taste. Beat and add the two slices of sliced bread. Flatten with a fork so that the bread is well soaked while we make a dough as similar as possible to a porridge in which no pieces of bread are noticeable.",
        "2. Add the minced meat and, with well-cleaned hands, mix until well incorporated. Divide the mixture of our hamburgers in six equal parts. We take each one of them, we roll it and flatten it between the palms of our hands. We can use a plate ring or some gadget to form hamburgers, but it is not necessary.",
        "3. Brush a wide frying pan or griddle with olive oil and heat over high heat. Place the hamburgers on it and sear them, without touching or flattening, for two or three minutes, lowering the heat halfway through cooking. Turn over, cover each hamburger with two slices of cheese, cover and cook on the other side for another two or three minutes. The time will depend on how well we want to cook the meat. Serve immediately."]
      },
      {
        "type": "hot_dog",
        "name": "Hot dog with minced meat and caramelized onions",
        "preparation": 10,
        "cooking": 40,
        "ingredients" : [" 4 Hot dog rolls", "4 fresh pork sausages", "150 g pork mince", 
        "6 tablespoons of mustard", "6 tablespoons of Mayonnaise "],
        "elaboration": ["1. Peel the onions and cut into julienne strips.",
        "2. Heat the oil in a casserole.",
        "3. Add the onion julienne, season with salt and cook for 40 minutes over very low heat, stirring occasionally to prevent sticking.",
        "4. Heat oil in a frying pan.",
        "5. Add the pork mince, salt and sauté for 4 minutes.",
        "6. Add half of the caramelized onion, mix and keep warm.",
        "7. In another frying pan brown the sausages for 4 minutes and salt.",
        "8. Pour 2 tablespoons of mustard and 2 tablespoons of mayonnaise in a bowl and mix.",
        "9. Open the rolls without separating the halves completely and fill them with the sausages and the minced meat mixed with onion.",
        "10. Garnish with a spoonful of the mustard and mayonnaise mixture and zigzag lines.",
        "11. Sprinkle with pepper and serve with more caramelized onion."]
      },
      {
        "type": "ice_cream",
        "name": "Strawberry ice cream",
        "preparation": 15,
        "cooking": 360,
        "ingredients" : ["500 g strawberries", "1 teaspoon of invert sugar or honey", "150 g sugar or powdered sugar", 
        "350 g very cold cream (minimum 35% fat)"],
        "elaboration": ["1.  Clean and cut the strawberries in half. Place in a container and place in the freezer for at least 1 hour. If we have them frozen beforehand, the recipe will be faster. In addition, we can take advantage of the strawberry season to freeze them and have them ready for the recipe.",
        "2. Place the sugar together with the strawberries in the food processor and blend until a slushy texture is obtained.",
        "3. Add the cream, which must be at cold temperature, together with the teaspoon of invert sugar or honey.",
        "4. Blend, 3 minutes, until a creamy texture is obtained as shown in the picture.",
        "5. Pour the mixture into a freezer-safe mold. Stir every half hour during the first 2 hours of freezing. Freeze for a minimum of 5 hours. Remove from freezer 15 minutes before serving. Decorate with wafers and toppings to taste."]
      },
      {
        "type": "macarons",
        "name": "Homemade macarons",
        "preparation": 30,
        "cooking": 30,
        "ingredients" : ["125 g almond flour", "125 g impalpable sugar", "4 eggs", 
        "100 g of common sugar", "Vegetable coloring, quantity needed", "Butter, quantity needed", "300 cc milk cream",
        "200 g white chocolate", "200 g dark chocolate"],
        "elaboration": ["1.  For the batter: place the egg whites in a double boiler with the sugar and beat until the mixture is diluted.",
        "2. Remove from the heat and beat while hot with a mixer until stiff.",
        "3. Add the dry ingredients previously mixed (sifted) and integrate into the previous preparation with wrapping movements so as not to lose the air. Integrate it in two times",
        "4. Separate part of the dough and color with the desired coloring. Integrate with a spatula.",
        "5. Place the preparation in a piping bag and give shape of alfajor lid in a plate with silicone, or buttered butter paper and sprinkled with powdered sugar.",
        "6. Let stand for 2 hours and bake in oven at 160 ° (medium) preheated for 4 minutes. Turn and bake again for 4 minutes.",
        "7. Let cool and take off.",
        "8. For the filling creams, heat the cream and emulsify to taste with mint, coffee, dulce de leche or strawberry paste. Integrate and then whip and set aside in refrigerator.",
        "9. Fill the lids to taste with piping bag.",
        "10. For the dark and white chocolate ganache, heat the milk cream (150 cc for each) and pour over chopped chocolate. Integrate and assemble."]
      },
      {
        "type": "nachos",
        "name": "Nachos with cheese, guacamole and chili with baked meat",
        "preparation": 15,
        "cooking": 15,
        "ingredients" : ["2 tomatoes", "1 spring onion", "2 limes", 
        "coriander", "300 g Minced veal", "150 ml Red wine", 
        "2 spoonfuls Fried tomato", "200 g Red beans", "1 teaspoon Paprika"
        "1 teaspoon Granulated garlic", "200 g dark chocolate"],
        "elaboration": ["1. For the pico de gallo: dice the tomatoes and the spring onion and put them in a bowl with the chopped parsley. Add the juice of the two limes, mix and let marinate at room temperature while preparing the rest of the preparations.",
        "2. For the chili con carne: fry the meat in a pan with olive oil until browned. Add the red wine and let it reduce to evaporate the alcohol. Add the tomato, red beans, salt and spices. Cook for 5 more minutes to integrate all the flavors and set aside.",
        "3. We prepare avocado",
        "4. For the nachos: spread them on a baking sheet and spread the sliced cheddar cheese cut into small pieces on top. Bake at 180 ºC for 3 minutes, serve with chili con carne, avocado cream, pico de gallo"]
      },
      {
        "type": "paella",
        "name": "Rice a banda",
        "preparation": 30,
        "cooking": 20,
        "ingredients" : ["Bomba rice 260 g", "Fish broth or fumet (three times the volume of the rice) 750 ml", "Cuttlefish 1", 
        "Shrimp 8", "Ripe tomatoes 2", "Salt", 
        "Garlic clove 1", "Sweet paprika", "Saffron"],
        "elaboration": ["1. We start with the broth, which we will prepare with rock fish and the tails and heads that we have been saving (monkfish, cod, hake...), as well as a potato, an onion and a little salt. You can follow our basic fish stock recipe here.",
        "2. In a paella pan with a little oil, brown the shrimp. Remove them and add the onion, which we brown over medium heat, then add the grated tomato, the cuttlefish and a clove of chopped garlic, frying until the tomato is well done. On the other hand, we peel the shrimps and crush the skins together with a little broth, strain it and add it to the broth.",
        "3. Now add the rice to the paella, salt, a little paprika and saffron and, of course, the boiling broth, in an approximate proportion of three to one with respect to the rice (three ladles of broth for each one of rice) and cook for 19 minutes, until it is dry and loose, incorporating the peeled shrimps at the end of the cooking. A good trick to make it perfect is to have some boiling broth on the side, in case we see that it is short in the middle of cooking. Finally, let it rest for a few minutes before serving."]
      },
      {
        "type": "pizza",
        "name": "Rice a banda",
        "preparation": 30,
        "cooking": 20,
        "ingredients" : ["Wheat flour 160 g", "Warm water 100 ml", "Fine salt teaspoon 1", 
        "Extra virgin olive oil tablespoon 1", "Dry baker's yeast or fresh yeast (a quarter of a packet) 7 g"],
        "elaboration": ["1. In a glass, pour the lukewarm water. Dissolve the yeast in the water",
        "2. In a bowl put the flour, salt and, little by little, pour the water with the yeast.",
        "3. It is easier if we knead little by little as we add the water, until all of it is poured in and a homogeneous dough is obtained.",
        "4. After this, place the dough on the worktop, cover your hands with flour so it doesn't stick and start kneading. If the dough remains sticky, add more flour. The dough must be dry enough so that it does not stick to the table or your hands, but not too dry, otherwise it may break in the oven.",
        "5. Once the dough is homogeneous, elastic, but not sticky, add the oil and knead again until it is completely integrated. Make a ball and make two incisions so that it can rise well.",
        "6. Return it to the bowl, cover it with a damp cloth and let it rest at room temperature."]
      },
      {
        "type": "sushi",
        "name": "Suhi",
        "preparation": 15,
        "cooking": 20,
        "ingredients" : ["Sushi rice 100 g", "Nori seaweed", "Fresh salmon 50 g", 
        "Avocado 1", "Cucumber 1", "Vinegar",
        "Sugar", "Salt"],
        "elaboration": ["1. Simply cook the rice (glutinous type or special for sushi) and then cool it with a fan after seasoning it with vinegar, sugar and salt.",
        "2. It is convenient to have all the ingredients ready when preparing the sushi, since they must be very fresh products and it is not convenient to waste time in handling them. Therefore, we will prepare a julienne of avocado and do the same with the cucumber to have it ready when we are going to form the makis. ",
        "3. As for the fish to be used, in this case we cut the salmon choosing the belly area to give it some cuts in strips. Here you can see perfectly how to do it. With everything ready, cut the nori seaweed sheet in two, put it on a mat or makisu lined with cling film, leaving the rough side on top, and spread the rice on it, pressing a little so that it adheres.",
        "4. In the center of the rice, place the fish strips, cucumber and avocado and optionally, a little wasabi, if we like the spicy touch of this condiment. Now all that is left is to roll the seaweed with the help of the mat and form a cylinder. When it is time to serve it, cut it into 8 portions, with the help of a moistened knife so that the rice does not get stuck."]
      },
    
    ]

# %%
recipes = db.recipes
recipes.insert_many(data_recipes)
